# %% [markdown]
# ### What are 10 (or more) questions that you hope to answer through your data analysis?
#
# No. | Question
# :-:|:-
# 1 | What is the happiest and "unhappiest" country?
# 2 | Which factors have the maximum correlation with happiness?
# 3 | How can the absence or presence of family affect happiness score?  #Answer with visualization
# 4| What is the average happiness score of each region?
# 5| Which countries rank the highest in each category of lifestyle?
# 6| How does each country’s dystopia score compare to the average? Is it higher or lower?
# 7| How has each country's ranks changed between 2019 and 2021?
# 8| Did any country experience a significant or impactful increase or decrease in happiness?
# 9| How has corruption impacted happiness during the two year?
# 10| Which year were people the happiest? What factors contributed to that?

# %%
import pandas
import seaborn
import matplotlib
pandas.options.display.max_columns = None
pandas.options.display.max_rows = None

seaborn.set(rc={'figure.figsize':(20,40)})


csv_data19 = pandas.read_csv("Happiness_data_2019.csv")

csv_data21 = pandas.read_csv("Happiness_data_2021.csv")

#csv_data19
csv_data21
# Out:
#                   Country name                  Regional indicator  \
# 0                      Finland                      Western Europe
# 1                      Denmark                      Western Europe
# 2                  Switzerland                      Western Europe
# 3                      Iceland                      Western Europe
# 4                  Netherlands                      Western Europe
# 5                       Norway                      Western Europe
# 6                       Sweden                      Western Europe
# 7                   Luxembourg                      Western Europe
# 8                  New Zealand               North America and ANZ
# 9                      Austria                      Western Europe
# 10                   Australia               North America and ANZ
# 11                      Israel        Middle East and North Africa
# 12                     Germany                      Western Europe
# ...

# %%
csv_data19.describe()

# %%
csv_data21.describe()

# %%
#Question 1 | What is the happiest and "unhappiest" country?


#happiest country data
happiest19 = csv_data19["Score"].max()
highest_score_row = csv_data19[ csv_data19['Score'] == csv_data19['Score'].max() ]
highest_score_row["Country or region"][0]

#happiest21 = csv_data21["Ladder score"].max()
#happiest21

# "unhappiest" country data
#uhappiest19 = csv_data19["Score"].min()
#uhappiest19

#uhappiest21 = csv_data21["Ladder score"].min()
#uhappiest21
# Out:
# 'Finland'

# %%
#Question 2 | Which factors have the maximum correlation with happiness?
#heatmap
#seaborn.heatmap(csv_data19.corr(), annot = True, cmap = 'viridis')

seaborn.heatmap(csv_data21.corr(), annot = False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
#Question 3 | How can the absence or presence of family affect happiness score?  #Answer with visualization

# %%
#Question 4| What is the average happiness score of each region?
csv_data21["Regional indicator"]

#seaborn.countplot(csv_data21["Regional indicator"])
# Out:
# 0                          Western Europe
# 1                          Western Europe
# 2                          Western Europe
# 3                          Western Europe
# 4                          Western Europe
# 5                          Western Europe
# 6                          Western Europe
# 7                          Western Europe
# 8                   North America and ANZ
# 9                          Western Europe
# 10                  North America and ANZ
# 11           Middle East and North Africa
# 12                         Western Europe
# 13                  North America and ANZ
# 14                         Western Europe
# 15            Latin America and Caribbean
# 16                         Western Europe
# 17             Central and Eastern Europe
# 18                  North America and ANZ
# 19                         Western Europe
# 20                         Western Europe
# 21           Middle East and North Africa
# ...

# %%
#Question 5| Which countries rank the highest in each category of lifestyle(social support, etc)?
# comparing bargraph that shows the highest in each category side by side.
#data for 2019
social19 = csv_data19["Social support"].max()
health19 = csv_data19["Healthy life expectancy"].max()
freedom19 = csv_data19["Freedom to make life choices"].max()
generosity19 = csv_data19["Generosity"].max()

#social19
#health19
#freedom19
#generosity19

#data for 2022
social21 = csv_data21["Social support"].max()
health21 = csv_data21["Healthy life expectancy"].max()
freedom21 = csv_data21["Freedom to make life choices"].max()
generosity21 = csv_data21["Generosity"].max()

#social21
#health21
#freedom21
#generosity21
# Out:
# 76.953

# %%
#Question 6| How does each country’s dystopia score compare to the average? Is it higher or lower?

# %%
#Question 7| How has each country's ranks changed between 2019 and 2021?

# %%
#Question 8| Did any country experience a significant or impactful increase or decrease in happiness?

# %%
#Question 9| How has corruption impacted happiness during the two year?

# %%
#Question 10| Which year were people the happiest? What factors contributed to that?
